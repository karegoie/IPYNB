# %%
import pandas as pd

# %%
pd.read_csv("./TPMdata.csv")
# Out:
#             gene     vpF1-1     vpF1-2     vpF1-3     vpF2-1     vpF2-2  \
# 0       g1000.t1  48.193691  43.675888  41.494019  63.410027  44.610500
# 1      g10000.t1   0.093001        NaN        NaN        NaN        NaN
# 2      g10004.t1   3.418670   4.699773   4.909054   5.318238   4.960538
# 3      g10005.t1   0.364417   0.034973   0.177490   0.086955   0.088182
# 4      g10006.t1   2.892773   2.100653   2.563712   2.611145   2.373052
# ...          ...        ...        ...        ...        ...        ...
# 36119   g9991.t1   1.387792   1.041935   1.219509   1.088961   0.614641
# 36120   g9996.t1   6.100643   3.450384   3.394312   1.425417   1.596063
# 36121   g9997.t1   4.795053   2.657095   4.374361   5.170162   6.264929
# 36122   g9998.t1   6.531012   7.795204   4.548237   4.555511   4.672304
# 36123   g9999.t1        NaN   0.101399        NaN        NaN   0.022799
#
#           vpF2-3     vpF3-1     vpF3-2     vpF3-3  ...      vpS1-3  \
# ...
